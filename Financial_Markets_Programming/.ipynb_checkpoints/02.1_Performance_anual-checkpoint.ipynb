# %%
# Import libraries
import PortfolioLab as pl
import cufflinks as cf
import pandas as pd

# Set cufflinks offline
cf.go_offline()

### Nova célula ###
MSCIs = pl.read_xlsl_MSCI(tickers=['MSCI_World_EUR', 'MSCI_EM_EUR'], 
                          nomes=['World €', 'EM €'])

### Nova célula ###
MSCIs.iplot(dimensions=pl.dimensions,
            title= 'MSCI World € vs MSCI EM €',
            yTitle='Valorização por cada 100 €uros investidos')

### Nova célula ###
DD = pl.compute_drawdowns(MSCIs)
DD.iplot(dimensions=pl.dimensions)

### Nova célula ###
# Compute Performance table
pl.compute_performance_table(MSCIs, freq='months')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# **Performance from 1998-12-31 to 2020-08-31 (≈ 21.7 years)**
#           CAGR   Return  StdDev  Sharpe   Max DD  MAR
# World €  5.92%  247.97%  14.38%    0.41  -54.15% 0.11
# EM €     8.94%  540.47%  19.92%    0.45  -56.08% 0.16

# %% [markdown]
# # Parte nova

# %% [markdown]
# Neste post vamos calcular retornos por anos civis. Algo que não é mais do que uma simples função: compute_yearly_returns()
#
# A função tem as seguintes opções. A normal start e end, que são úteis para fazer mais que um quadro quando são muitos anos **e** a função style. A função style pode ser "table" (que é a que está por defeito) ou chart. Caso a opção chart seja escolhida um gráfico seaborn heatmap colorido é feito, em vez do quadro "normal".

# %%
returns_until_2008 = pl.compute_yearly_returns(MSCIs, end='2008', title='Yearly Returns from 1998 to 2008')
returns_until_2008
# Out:
# At least parameter has a wrong input

# %%
returns_after_2008 = pl.compute_yearly_returns(MSCIs, start='2009', title='Yearly Returns since 2009')
returns_after_2008
# Out:
# At least parameter has a wrong input

# %%
returns_until_2008 = pl.compute_yearly_returns(MSCIs, style='chart', end='2008', title='Yearly Returns from 1998 to 2008')
returns_until_2008;

# %%
returns_after_2008 = pl.compute_yearly_returns(MSCIs, style='chart', start='2009', title='Yearly Returns since 2009')
returns_after_2008;

# %% [markdown]
# As opções não se ficam por aqui. Podem escolher números coloridos na tabela com a opção **color=True** e por último a opção **style='string'**, que é a ideal para gravar em ficheiro .CSV e ser lido por outro software como R por exemplo.

# %%
pl.compute_yearly_returns(MSCIs, end='2008', title='Yearly Returns from 1998 to 2008', color=True)
# Out:
# **Yearly Returns from 1998 to 2008**
# <style  type="text/css" >
#     #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col0 {
#             color:  black;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col1 {
#             color:  green;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col2 {
#             color:  red;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col3 {
#             color:  red;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col4 {
#             color:  red;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col5 {
#             color:  green;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col6 {
#             color:  green;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col7 {
#             color:  green;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col8 {
#             color:  green;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col9 {
#             color:  red;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col10 {
#             color:  red;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col0 {
#             color:  black;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col1 {
#             color:  green;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col2 {
#             color:  red;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col3 {
#             color:  green;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col4 {
#             color:  red;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col5 {
#             color:  green;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col6 {
#             color:  green;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col7 {
#             color:  green;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col8 {
#             color:  green;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col9 {
#             color:  green;
#         }    #T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col10 {
#             color:  red;
#         }</style><table id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1998</th>        <th class="col_heading level0 col1" >1999</th>        <th class="col_heading level0 col2" >2000</th>        <th class="col_heading level0 col3" >2001</th>        <th class="col_heading level0 col4" >2002</th>        <th class="col_heading level0 col5" >2003</th>        <th class="col_heading level0 col6" >2004</th>        <th class="col_heading level0 col7" >2005</th>        <th class="col_heading level0 col8" >2006</th>        <th class="col_heading level0 col9" >2007</th>        <th class="col_heading level0 col10" >2008</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536level0_row0" class="row_heading level0 row0" >World €</th>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col0" class="data row0 col0" >0.00%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col1" class="data row0 col1" >46.84%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col2" class="data row0 col2" >-7.03%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col3" class="data row0 col3" >-11.98%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col4" class="data row0 col4" >-31.73%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col5" class="data row0 col5" >11.28%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col6" class="data row0 col6" >6.95%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col7" class="data row0 col7" >26.78%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col8" class="data row0 col8" >7.93%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col9" class="data row0 col9" >-1.18%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row0_col10" class="data row0 col10" >-37.24%</td>
#             </tr>
#             <tr>
#                         <th id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536level0_row1" class="row_heading level0 row1" >EM €</th>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col0" class="data row1 col0" >0.00%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col1" class="data row1 col1" >94.95%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col2" class="data row1 col2" >-25.92%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col3" class="data row1 col3" >2.94%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col4" class="data row1 col4" >-20.24%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col5" class="data row1 col5" >30.02%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col6" class="data row1 col6" >16.88%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col7" class="data row1 col7" >55.04%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col8" class="data row1 col8" >18.57%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col9" class="data row1 col9" >26.11%</td>
#                         <td id="T_a8774d9d_fb80_11ea_9b63_d45d64d33536row1_col10" class="data row1 col10" >-50.76%</td>
#             </tr>
#     </tbody></table>

# %%
returns_after_2008 = pl.compute_yearly_returns(MSCIs, start='2009', title='Yearly Returns since 2009', color=True)
returns_after_2008
# Out:
# **Yearly Returns since 2009**
# <style  type="text/css" >
#     #T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col0 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col1 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col2 {
#             color:  red;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col3 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col4 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col5 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col6 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col7 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col8 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col9 {
#             color:  red;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col10 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col11 {
#             color:  red;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col0 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col1 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col2 {
#             color:  red;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col3 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col4 {
#             color:  red;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col5 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col6 {
#             color:  red;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col7 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col8 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col9 {
#             color:  red;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col10 {
#             color:  green;
#         }    #T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col11 {
#             color:  red;
#         }</style><table id="T_a87c3006_fb80_11ea_9da2_d45d64d33536" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2009</th>        <th class="col_heading level0 col1" >2010</th>        <th class="col_heading level0 col2" >2011</th>        <th class="col_heading level0 col3" >2012</th>        <th class="col_heading level0 col4" >2013</th>        <th class="col_heading level0 col5" >2014</th>        <th class="col_heading level0 col6" >2015</th>        <th class="col_heading level0 col7" >2016</th>        <th class="col_heading level0 col8" >2017</th>        <th class="col_heading level0 col9" >2018</th>        <th class="col_heading level0 col10" >2019</th>        <th class="col_heading level0 col11" >2020</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a87c3006_fb80_11ea_9da2_d45d64d33536level0_row0" class="row_heading level0 row0" >World €</th>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col0" class="data row0 col0" >26.72%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col1" class="data row0 col1" >20.14%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col2" class="data row0 col2" >-1.84%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col3" class="data row0 col3" >14.75%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col4" class="data row0 col4" >21.86%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col5" class="data row0 col5" >20.14%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col6" class="data row0 col6" >11.03%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col7" class="data row0 col7" >11.39%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col8" class="data row0 col8" >8.10%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col9" class="data row0 col9" >-3.58%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col10" class="data row0 col10" >30.76%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row0_col11" class="data row0 col11" >-0.76%</td>
#             </tr>
#             <tr>
#                         <th id="T_a87c3006_fb80_11ea_9da2_d45d64d33536level0_row1" class="row_heading level0 row1" >EM €</th>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col0" class="data row1 col0" >73.44%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col1" class="data row1 col1" >27.48%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col2" class="data row1 col2" >-15.44%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col3" class="data row1 col3" >16.80%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col4" class="data row1 col4" >-6.49%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col5" class="data row1 col5" >11.81%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col6" class="data row1 col6" >-4.87%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col7" class="data row1 col7" >14.94%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col8" class="data row1 col8" >21.00%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col9" class="data row1 col9" >-9.91%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col10" class="data row1 col10" >21.07%</td>
#                         <td id="T_a87c3006_fb80_11ea_9da2_d45d64d33536row1_col11" class="data row1 col11" >-5.50%</td>
#             </tr>
#     </tbody></table>

# %%
# Opção String para fazer um ficheiro .CSV com o simbolo de % já embutido
returns_after_2008 = pl.compute_yearly_returns(MSCIs, start='2009', title='Yearly Returns since 2009', style='string')
returns_after_2008
# Out:
#            2009    2010     2011    2012    2013    2014    2015    2016   2017    2018    2019    2020
# World €  26.72%  20.14%   -1.84%  14.75%  21.86%  20.14%  11.03%  11.39%   8.1%  -3.58%  30.76%  -0.76%
# EM €     73.44%  27.48%  -15.44%   16.8%  -6.49%  11.81%  -4.87%  14.94%  21.0%  -9.91%  21.07%   -5.5%

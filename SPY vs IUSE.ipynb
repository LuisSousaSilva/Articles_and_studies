# %%
# %matplotlib inline

# importing libraries  
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.offline as py
import cufflinks as cf
import seaborn as sns
import pandas as pd
import numpy as np
import quandl
import plotly
import time

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from IPython.display import Markdown, display
from matplotlib.ticker import FuncFormatter
from pandas.core.base import PandasObject
from datetime import datetime

pd.options.display.float_format = '{:,.2f}'.format

# Setting pandas dataframe display options
pd.set_option("display.max_rows", 20)
pd.set_option('display.width', 800)
pd.set_option('max_colwidth', 800)

# Set plotly offline
init_notebook_mode(connected=True)

# Set matplotlib style
plt.style.use('seaborn')

# Set cufflinks offline
cf.go_offline()

# Defining today's Date
from datetime import date
today = date.today()

import PortfolioLab as pl
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# [<img style="float: right;" src="https://www.futureproof.pt/files/f_photos/f_shares/logo-future-proof_smaller.png" alt="FP" border="0">](https://www.futureproof.pt/)

# %%
# Downloading funds and creating quotes and returns dataframes
Begin = '2000-03-10'
# End = '2017-08-20' # Só activas se quiseres que acabe num dia especifíco 

Tickers = ['SPY.US', 'IUSE.LSE']
ETF_Tickers =['SPY', 'IUSE']

ETFs2 = pd.DataFrame()

# Download
for ticker in Tickers:
    try:
        url = "https://eodhistoricaldata.com/api/eod/" + str(ticker) + "?api_token=5c982bff80deb2.22427269&period=d."
        ETF = pd.read_csv(url, index_col = 'Date', parse_dates = True)[['Adjusted_close']].iloc[:-1, :]
        ETFs2 = ETFs2.merge(ETF, left_index = True, right_index = True, how='outer')
    except:
        print('Download of fund ' + ticker + ' failed')
    
ETFs2.columns = ETF_Tickers
ETFs2 = ETFs2.fillna(method='ffill')
ETFs2 = ETFs2.replace(to_replace=0, method='ffill')

ETFs2 = ETFs2.loc['2000-07-07':]

# %%
fundos = pl.normalize(ETFs2.dropna())
fundos.iplot(dimensions=pl.dimensions, title='SPY vs IUSE (iShares S&P 500 eur hedged)')

# %%
pl.compute_performance_table(fundos)
# Out:
# **Performance from 2010-10-01 to 2021-02-19 (≈ 10.4 years)**
#         CAGR   Return  StdDev  Sharpe   Max DD  MAR
# SPY   14.73%  317.44%  16.87%    0.87  -33.72% 0.44
# IUSE  12.54%  241.69%  15.80%    0.79  -34.75% 0.36

# %%
ratio = fundos ['IUSE'] / fundos['SPY']
ratio = pd.DataFrame(ratio)
ratio.index = pd.to_datetime(ratio.index)
ratio.columns=['Ratio']

ratio['60 days MA'] = ratio['Ratio'].rolling('60D').mean()
ratio.iplot(dimensions=pl.dimensions, title="Rácio entre SPY e IUSN")

# %%
pl.compute_yearly_returns(ratio)
# Out:
# **Yearly Returns**
# <style  type="text/css" >
# </style><table id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2010</th>        <th class="col_heading level0 col1" >2011</th>        <th class="col_heading level0 col2" >2012</th>        <th class="col_heading level0 col3" >2013</th>        <th class="col_heading level0 col4" >2014</th>        <th class="col_heading level0 col5" >2015</th>        <th class="col_heading level0 col6" >2016</th>        <th class="col_heading level0 col7" >2017</th>        <th class="col_heading level0 col8" >2018</th>        <th class="col_heading level0 col9" >2019</th>        <th class="col_heading level0 col10" >2020</th>        <th class="col_heading level0 col11" >2021</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536level0_row0" class="row_heading level0 row0" >Ratio</th>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row0_col0" class="data row0 col0" >0.01%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row0_col1" class="data row0 col1" >-1.97%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row0_col2" class="data row0 col2" >-3.63%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row0_col3" class="data row0 col3" >0.81%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row0_col4" class="data row0 col4" >0.91%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row0_col5" class="data row0 col5" >-1.47%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row0_col6" class="data row0 col6" >-2.30%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row0_col7" class="data row0 col7" >-2.19%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row0_col8" class="data row0 col8" >-4.01%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row0_col9" class="data row0 col9" >-3.73%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row0_col10" class="data row0 col10" >-2.97%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row0_col11" class="data row0 col11" >0.88%</td>
#             </tr>
#             <tr>
#                         <th id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536level0_row1" class="row_heading level0 row1" >60 days MA</th>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row1_col0" class="data row1 col0" >-0.13%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row1_col1" class="data row1 col1" >-1.46%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row1_col2" class="data row1 col2" >-1.65%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row1_col3" class="data row1 col3" >-1.09%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row1_col4" class="data row1 col4" >-0.79%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row1_col5" class="data row1 col5" >-1.13%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row1_col6" class="data row1 col6" >-1.96%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row1_col7" class="data row1 col7" >-2.22%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row1_col8" class="data row1 col8" >-3.33%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row1_col9" class="data row1 col9" >-3.47%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row1_col10" class="data row1 col10" >-2.66%</td>
#                         <td id="T_aecaabdd_73b6_11eb_a78e_d45d64d33536row1_col11" class="data row1 col11" >-0.31%</td>
#             </tr>
#     </tbody></table>

# %%
monthly_costs = ratio.resample('M').last()[['60 days MA']]['2011':].pct_change().dropna() * 100
monthly_costs = monthly_costs.reset_index()

monthly_costs.Date=monthly_costs.Date.astype(str)
monthly_costs = round(monthly_costs, 2)

pl.ichart(round(monthly_costs),
          title='Estimated monthly costs of currency hedging',
          style='bar',
          bar_x_axis=monthly_costs['Date'],
          bar_y_axis=monthly_costs['60 days MA'],
          bar_labels=monthly_costs['60 days MA'],
          bar_colors=['royalblue'] * 1000,
          showlegend=False,
          yticksuffix='%')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="f9a0b7e9-07fd-413c-a5f8-7faa9b67dd8c" class="plotly-graph-div" style="height:500px; width:950px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9a0b7e9-07fd-413c-a5f8-7faa9b67dd8c")) {                    Plotly.newPlot(                        "f9a0b7e9-07fd-413c-a5f8-7faa9b67dd8c",                        [{"marker": {"color": "royalblue"}, "name": "-0.27", "type": "bar", "x": ["2011-02-28"], "y": [-0.27]}, {"marker": {"color": "royalblue"}, "name": "-0.02", "type": "bar", "x": ["2011-03-31"], "y": [-0.02]}, {"marker": {"color": "royalblue"}, "name": "0.08", "type": "bar", "x": ["2011-04-30"], "y": [0.08]}, {"marker": {"color": "royalblue"}, "name": "-0.18", "type": "bar", "x": ["2011-05-31"], "y": [-0.18]}, {"marker": {"color": "royalblue"}, "name": "0.09", "type": "bar", "x": ["2011-06-30"], "y": [0.09]}, {"marker": {"color": "royalblue"}, "name": "0.02", "type": "bar", "x": ["2011-07-31"], "y": [0.02]}, {"marker": {"color": "royalblue"}, "name": "-0.15", "type": "bar", "x": ["2011-08-31"], "y": [-0.15]}, {"marker": {"color": "royalblue"}, "name": "-0.06", "type": "bar", "x": ["2011-09-30"], "y": [-0.06]}, {"marker": {"color": "royalblue"}, "name": "-0.53", "type": "bar", "x": ["2011-10-31"], "y": [-0.53]}, {"marker": {"color": "royalblue"}, "name": "-0.44", "type": "bar", "x": ["2011-11-30"], "y": [-0.44]}, {"marker": {"color": "royalblue"}, "name": "0.06", "type": "bar", "x": ["2011-12-31"], "y": [0.06]}, {"marker": {"color": "royalblue"}, "name": "-0.22", "type": "bar", "x": ["2012-01-31"], "y": [-0.22]}, {"marker": {"color": "royalblue"}, "name": "-0.17", "type": "bar", "x": ["2012-02-29"], "y": [-0.17]}, {"marker": {"color": "royalblue"}, "name": "-0.09", "type": "bar", "x": ["2012-03-31"], "y": [-0.09]}, {"marker": {"color": "royalblue"}, "name": "-0.0", "type": "bar", "x": ["2012-04-30"], "y": [-0.0]}, {"marker": {"color": "royalblue"}, "name": "0.15", "type": "bar", "x": ["2012-05-31"], "y": [0.15]}, {"marker": {"color": "royalblue"}, "name": "-0.34", "type": "bar", "x": ["2012-06-30"], "y": [-0.34]}, {"marker": {"color": "royalblue"}, "name": "-0.67", "type": "bar", "x": ["2012-07-31"], "y": [-0.67]}, {"marker": {"color": "royalblue"}, "name": "-0.07", "type": "bar", "x": ["2012-08-31"], "y": [-0.07]}, {"marker": {"color": "royalblue"}, "name": "0.05", "type": "bar", "x": ["2012-09-30"], "y": [0.05]}, {"marker": {"color": "royalblue"}, "name": "-0.08", "type": "bar", "x": ["2012-10-31"], "y": [-0.08]}, {"marker": {"color": "royalblue"}, "name": "-0.04", "type": "bar", "x": ["2012-11-30"], "y": [-0.04]}, {"marker": {"color": "royalblue"}, "name": "-0.17", "type": "bar", "x": ["2012-12-31"], "y": [-0.17]}, {"marker": {"color": "royalblue"}, "name": "-0.24", "type": "bar", "x": ["2013-01-31"], "y": [-0.24]}, {"marker": {"color": "royalblue"}, "name": "-0.11", "type": "bar", "x": ["2013-02-28"], "y": [-0.11]}, {"marker": {"color": "royalblue"}, "name": "-0.0", "type": "bar", "x": ["2013-03-31"], "y": [-0.0]}, {"marker": {"color": "royalblue"}, "name": "-0.15", "type": "bar", "x": ["2013-04-30"], "y": [-0.15]}, {"marker": {"color": "royalblue"}, "name": "0.0", "type": "bar", "x": ["2013-05-31"], "y": [0.0]}, {"marker": {"color": "royalblue"}, "name": "0.09", "type": "bar", "x": ["2013-06-30"], "y": [0.09]}, {"marker": {"color": "royalblue"}, "name": "-0.08", "type": "bar", "x": ["2013-07-31"], "y": [-0.08]}, {"marker": {"color": "royalblue"}, "name": "-0.17", "type": "bar", "x": ["2013-08-31"], "y": [-0.17]}, {"marker": {"color": "royalblue"}, "name": "-0.13", "type": "bar", "x": ["2013-09-30"], "y": [-0.13]}, {"marker": {"color": "royalblue"}, "name": "-0.21", "type": "bar", "x": ["2013-10-31"], "y": [-0.21]}, {"marker": {"color": "royalblue"}, "name": "-0.09", "type": "bar", "x": [" ...

# %%
from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di # Example: di.display_html('<h3>%s:</h3>' % str, raw=True)

# This line will hide code by default when the notebook is exported as HTML
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)

# This line will add a button to toggle visibility of code blocks, for use with the HTML export version
di.display_html('''<button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Código ON/OFF</button>''', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Código ON/OFF</button>
